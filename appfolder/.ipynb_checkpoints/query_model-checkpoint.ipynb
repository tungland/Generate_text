# %% [markdown]
# # Inspiser en word2vec-modell
#
# Installer gensim og test

# %%
from gensim.models import KeyedVectors
from gensim import models
from IPython.display import Markdown

# %% [markdown]
# Last ned modellen og ta den inn i notebooken

# %%
model_file = 'fifth_capital_ddc.model' # eller annet filnavn - pass på sti

model = KeyedVectors.load(model_file)    #load_word2vec_format(model_file, binary=True)
d = model.wv
del model

# %% [markdown]
# Test med most_similar for forskjellige ord for evaluering.

# %%
d.get_vector('helse')
# Out:
# array([-2.2655003 , -2.7335954 ,  2.3382518 ,  0.90491897, -1.092454  ,
#        -0.5933758 ,  0.9386178 , -1.4529421 , -3.2095501 , -5.42064   ,
#         5.080924  , -1.4620608 , -2.3976908 ,  0.15059079,  1.0496217 ,
#        -1.1031585 ,  4.7365336 ,  1.6003933 ,  0.36756793,  1.2415788 ,
#        -0.3915685 , -0.9368924 ,  2.295742  ,  1.1642853 ,  2.303597  ,
#        -1.273042  , -0.8713483 ,  1.5805764 ,  3.390258  ,  4.983209  ,
#         2.8833687 ,  3.886329  ,  2.921982  , -0.7138787 , -3.348163  ,
#        -1.341756  ,  3.144157  , -1.096457  ,  0.8519767 ,  0.14382154,
#         1.1545657 , -1.005668  ,  3.7145069 , -1.9548186 ,  1.8511237 ,
#        -1.3385831 , -2.0918448 , -1.164659  ,  1.3763753 , -2.1168685 ],
#       dtype=float32)

# %%
d.most_similar('beinbrudd', topn=60)
# Out:
# [('astmaanfall', 0.8421464562416077),
#  ('munnsår', 0.8192625045776367),
#  ('krampeanfall', 0.8161188364028931),
#  ('infarkt', 0.8100883364677429),
#  ('gangren', 0.798666775226593),
#  ('panikkanfall', 0.7952818870544434),
#  ('ulcus', 0.7928065657615662),
#  ('brokk', 0.7917650938034058),
#  ('migreneanfall', 0.7915753126144409),
#  ('allergen', 0.7865543365478516),
#  ('hjerteanfall', 0.785432755947113),
#  ('hudutslett', 0.780768096446991),
#  ('liggesår', 0.7787708044052124),
#  ('hudproblemer', 0.7786063551902771),
#  ('kontrastmiddel', 0.7776268720626831),
#  ('årebetennelse', 0.7748534083366394),
#  ('adenom', 0.7732738852500916),
#  ('aneurisme', 0.7693237066268921),
#  ('herpes', 0.7663745880126953),
#  ('emfysem', 0.7659100890159607),
#  ('periodontitt', 0.7625921964645386),
#  ('trombocytopeni', 0.7625473737716675),
#  ('hjerneblødninger', 0.7619068026542664),
#  ('tarmslyng', 0.7618071436882019),
#  ('lesjoner', 0.7604786157608032),
#  ('delir', 0.7590231895446777),
#  ('perikarditt', 0.7577117681503296),
#  ('høysnue', 0.7575833201408386),
#  ('strømbrudd', 0.7568994760513306),
#  ('meningokokksepsis', 0.7568891644477844),
#  ('Kvalme', 0.7562915086746216),
#  ('utslett', 0.7551723122596741),
#  ('elveblest', 0.754779040813446),
#  ('traume', 0.7540249824523926),
#  ('ileus', 0.7526525855064392),
#  ('lesjon', 0.7521300911903381),
#  ('forbrenninger', 0.7518245577812195),
#  ('hemorroider', 0.7514994740486145),
#  ('abscess', 0.7509976625442505),
#  ('allergireaksjoner', 0.7509551048278809),
#  ('infarkter', 0.7509072422981262),
#  ('angstanfall', 0.7493822574615479),
#  ('fremmedlegeme', 0.7478955984115601),
#  ('hudlidelser', 0.7478764057159424),
#  ('cyster', 0.7474035620689392),
#  ('sårskader', 0.7468683123588562),
#  ('infiltrater', 0.7464084625244141),
#  ('benbrudd', 0.7462959289550781),
#  ('polypper', 0.7461956143379211),
#  ('Blødninger', 0.7459642291069031),
#  ('rhinitt', 0.7454788088798523),
#  ('embolier', 0.7444557547569275),
#  ('antibiotikum', 0.7436583638191223),
#  ('hematom', 0.7432769536972046),
#  ('pneumoni', 0.7418659925460815),
#  ('dyspné', 0.7411534190177917),
#  ('bihulebetennelse', 0.7407432794570923),
#  ('lungebetennelser', 0.7403059005737305),
#  ('åreknuter', 0.7396343350410461),
#  ('pusteproblemer', 0.7391711473464966)]

# %%
T = ""
for x in "vitenskap samfunnsvitenskap sosiologi sosialantropologi".split():
    try:
        text = f"### {x} \n {', '.join([x[0] for x in d.most_similar(x, topn=10)])}\n\n"
    except:
        text = f"### {x} \n"
    T += text
    
Markdown(T)
# Out:
# ### vitenskap
#  naturvitenskap, filosofi, naturvitenskapene, metafysikk, humanisme, kapitalisme, evolusjon, naturvitenskapen, retorikk, antropologi
#
# ### samfunnsvitenskap
#  humaniora, naturvitenskap, sosialøkonomi, sosiologi, jus, juss, samfunnsforskning, organisasjonsteori, lingvistikk, sosialantropologi
#
# ### sosiologi
#  psykologi, sosialantropologi, religionsvitenskap, religionshistorie, statsvitenskap, litteraturvitenskap, lingvistikk, samfunnsvitenskap, sosialpsykologi, antropologi
#
# ### sosialantropologi
#  statsvitenskap, litteraturvitenskap, etnologi, sosiologi, religionsvitenskap, teatervitenskap, etnografi, folkloristikk, kriminologi, lingvistikk

# %%
T = ""
for x in "is".split():
    try:
        text = f"### {x} \n {', '.join([x[0] for x in d.most_similar(x, topn=10)])}\n\n"
    except:
        text = f"### {x} \n"
    T += text
    
Markdown(T)
# Out:
# ### is
#  ål, snø, kram, sørpe, most, åte, speed, not, slaps, graut

# %%
T = ""
for x in "OECD PISA TIMSS elever lærere".split():
    try:
        text = f"### {x} \n {', '.join([x[0] for x in d.most_similar(x, topn=20)])}\n\n"
    except:
        text = f"### {x} \n"
    T += text
    
Markdown(T)
# Out:
# ### OECD
#  UNESCO, OECDs, Verdensbanken, Eurostat, ILO, IMF, FAO, ESA, WTO, EFTA, lEA, GATT, Schengen, EF, WHO, Europakommisjonen, NPM, IPCC, Europarådet, International
#
# ### PISA
#  TIMSS, PIRLS, Elevundersøkelsen, engelskfaget, fonetikk, mappevurdering, Regresjonsanalyse, ICDP, religionsfaget, Læreplanene, læremidlene, realfagene, kroppsøvingsfaget, Empirien, ITU, naturfagene, intensivopplæringen, studieforhold, forskningskvalitet, eksamensoppgåver
#
# ### TIMSS
#  PISA, PIRLS, Regresjonsanalyse, Elevundersøkelsen, lærervurdering, avgangsprøven, Progresjon, engelskfaget, kombinatorikk, praksisrettet, hovedtrinnene, VKI, fellesundervisning, studieforhold, BUA, profesjonsutdanninger, Prestasjoner, profesjonsutdanningen, utdanningsprogrammene, Sammenlikne
#
# ### elever
#  lærere, studenter, lærerne, studentene, elevene, åringene, ungdommer, assistentene, deltakere, personalet, deltakerne, foreldre, ungdommene, karakterer, medelever, åringer, jenter, instruktørene, barna, skolene
#
# ### lærere
#  elever, studenter, lærerne, studentene, sykepleiere, førskolelærere, pedagoger, veiledere, fagfolk, ledere, fagpersoner, assistentene, rektorer, personalet, veilederne, sosialarbeidere, instruktører, skolene, skoleledere, læreme

# %% [markdown]
# # Make graph

# %%
import pandas as pd
import dhlab.graph_networkx_louvain as gnl
import networkx as nx

# %%
[x[0] for x in d.most_similar('Ellen', topn=30)]
# Out:
# ['Tove',
#  'Bjørn',
#  'Elisabeth',
#  'Randi',
#  'Anne',
#  'Trine',
#  'Knut',
#  'Arne',
#  'Ingrid',
#  'Karin',
#  'Tor',
#  'Tore',
#  'Lars',
#  'Odd',
#  'Marie',
#  'Nils',
#  'Jens',
#  'Einar',
#  'Rune',
#  'Berit',
#  'Erik',
#  'Inger',
#  'Hilde',
#  'Lisbeth',
#  'Olsen',
#  'Bente',
#  'Berg',
#  'Kristian',
#  'Geir',
#  'Marit']

# %%
def make_edges(w, topn=20, visited=None, model = d, level = 0):
    edges = []
    if w not in visited:
        visited.append(w)
        try:
            gdata =  model.most_similar(w, topn=topn)
            edges += [(w, g[0], g[1]) for g in gdata]
            #print(visited)
            if level > 0:
                for g in gdata:
                    l = level - 1
                    edges += make_edges(g[0], topn=topn, visited = visited, level=l)
                    #print(l,edge)
        except:
            pass
            #print("problem", w)
    return edges

def graf(w, model = d, top = 20):
    edges = make_edges(w, topn = top, visited=[], model=model,level = 1)
    G = nx.DiGraph()
    G.add_weighted_edges_from(edges)
    return G

# %%
G = graf('TIMSS',model=d, top=15)

gnl.show_communities(G)
# Out:
# TIMSS-studieforhold :  TIMSS, studieforhold, fellesundervisning, avgangsprøven, kombinatorikk, lærervurdering, hovedtrinnene, engelskfaget, PIRLS, BUA
#
# PISA-Konfidensintervall :  PISA, Konfidensintervall, inclusion, forskningsintervjuet, gjennomsnittsnivået, Significance, grunntrekkene, Norcross, FORSKNINGSMETODER, IDEAS, Reason, skjermingsstøtte, PÅRØRENDEINVOLVERING, NERVESYSTEMETS, SYDEN
#
# praksisrettet-aktivitetsbasert :  praksisrettet, aktivitetsbasert, Administrativt, Personell, Finansiering, BFD, Næringslivets, HELTEF, Årsverk, allmennlegetjenesten, kommunesektoren, Prosjektene, Hovedorganisasjon, Boks, FoU, Bioteknologisk
#
# Regresjonsanalyse-Simulering :  Regresjonsanalyse, Simulering, Familiesituasjon, Organiseringsmodell, Effleuragefriksjoner, Aktivitetsbredde, Helseeffekt, Faktoranalyse, Nivåer, Beleggsprosent, Utdanningsbakgrunn, Datatilfang, Rater, Korrigerte, Kvalitativt, Kostnadsnivå
#
# Elevundersøkelsen-Rektorer :  Elevundersøkelsen, Rektorer, Arbeidslivsundersøkelsene, samordningsmodeller, Hanisch, gjennomsnittskår, totalutvalget, gruppemøter, Midtbyen, klassinger, brukerkontakter, Hemne, miljøkostnader, Forts, Kvalitetsreformen, gråsoneprosedyrer
#
# VKI-helsefremmingsbevegelsen :  VKI, helsefremmingsbevegelsen, Profesjonsmakt, polyvagal, virkemiddelbruken, Hopen, søndager, sjukhem, ungdomsarbeiderfag, landssamlingen, Utdanningsdirektoratets, Vifladt, Ammerud, grupperom, Vg, Bjurslåtts
#
# Progresjon-sterni :  Progresjon, sterni, quadriceps, proksimal, curl, Utposning, koagulasjonssystemet, Nyrebekken, Dermatofytisk, Enhåndsløfting, neseskillevegg, skulderbue, Bevegeliggjøre, bulrer, Opprettholdelse, Tøyning

# %%
gnl.show_graph(G, spread=0.01)

# %%
from collections import Counter

# %%
def show_centralities(G, size=10):
    cols = [Counter(nx.betweenness_centrality(G)).most_common(size),
            Counter(nx.degree_centrality(G)).most_common(size),
            Counter(nx.in_degree_centrality(G)).most_common(size),
            Counter(nx.out_degree_centrality(G)).most_common(size)
           ]
    names = ["Betweennes", "Degree", "Indegree", "Outdegree"]
    res = zip(names, cols)
    cents = pd.concat(map(lambda x: pd.DataFrame(x[1], columns =['index', x[0]]).set_index('index'), res), axis = 1)
    return cents

# %%
G = graf('is', model=d,top=20)
(show_centralities(G, 20).fillna(0)
    .sort_values(by=['Degree','Indegree','Betweennes','Outdegree',], ascending=False)
    .style
    .background_gradient(axis = 1))
# Out:
# <style type="text/css">
# #T_cf821_row0_col0, #T_cf821_row1_col0, #T_cf821_row2_col0, #T_cf821_row3_col0, #T_cf821_row4_col0, #T_cf821_row5_col0, #T_cf821_row6_col0, #T_cf821_row7_col0, #T_cf821_row8_col0, #T_cf821_row9_col0, #T_cf821_row10_col0, #T_cf821_row11_col0, #T_cf821_row12_col0, #T_cf821_row13_col3, #T_cf821_row14_col2, #T_cf821_row15_col2, #T_cf821_row16_col2, #T_cf821_row17_col2, #T_cf821_row18_col2, #T_cf821_row19_col2, #T_cf821_row20_col0, #T_cf821_row20_col1, #T_cf821_row20_col3, #T_cf821_row21_col0, #T_cf821_row21_col1, #T_cf821_row21_col3, #T_cf821_row22_col0, #T_cf821_row22_col1, #T_cf821_row22_col3, #T_cf821_row23_col0, #T_cf821_row23_col1, #T_cf821_row23_col3, #T_cf821_row24_col0, #T_cf821_row24_col1, #T_cf821_row24_col3, #T_cf821_row25_col0, #T_cf821_row25_col1, #T_cf821_row25_col3, #T_cf821_row26_col0, #T_cf821_row26_col1, #T_cf821_row26_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_cf821_row0_col1, #T_cf821_row1_col1, #T_cf821_row2_col1, #T_cf821_row3_col1, #T_cf821_row4_col1, #T_cf821_row5_col1, #T_cf821_row6_col1, #T_cf821_row7_col1, #T_cf821_row8_col1, #T_cf821_row9_col1, #T_cf821_row10_col1, #T_cf821_row11_col1, #T_cf821_row12_col1, #T_cf821_row13_col1, #T_cf821_row14_col1, #T_cf821_row15_col1, #T_cf821_row16_col1, #T_cf821_row17_col1, #T_cf821_row18_col1, #T_cf821_row19_col1, #T_cf821_row20_col2, #T_cf821_row21_col2, #T_cf821_row22_col2, #T_cf821_row23_col2, #T_cf821_row24_col2, #T_cf821_row25_col2, #T_cf821_row26_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_cf821_row0_col2 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_cf821_row0_col3 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_cf821_row1_col2, #T_cf821_row2_col2 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_cf821_row1_col3, #T_cf821_row2_col3 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_cf821_row3_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_cf821_row3_col3 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_cf821_row4_col2 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_cf821_row4_col3 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_cf821_row5_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_cf821_row5_col3 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_cf821_row6_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_cf821_row6_col3 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_cf821_row7_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_cf821_row7_col3 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_cf821_row8_col2, #T_cf821_row9_col2 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_cf821_row8_col3, #T_cf821_row9_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_cf821_row10_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_cf821_row10_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_cf821_row11_col2 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_cf821_row11_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_cf821_row12_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_cf821_row12_col3 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_cf821_row13_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_cf821_row13_col2 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_cf821_row14_col0, #T_cf821_row16_col0, #T_cf821_row17_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_cf821_row14_col3 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_cf821_row15_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_cf821_row15_col3 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_cf821_row16_col3, #T_cf821_row17_col3 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_cf821_row18_col0, #T_cf821_row19_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_cf821_row18_col3, #T_cf821_row19_col3 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf821">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf821_level0_col0" class="col_heading level0 col0" >Betweennes</th>
#       <th id="T_cf821_level0_col1" class="col_heading level0 col1" >Degree</th>
#       <th id="T_cf821_level0_col2" class="col_heading level0 col2" >Indegree</th>
#       <th id="T_cf821_level0_col3" class="col_heading level0 col3" >Outdegree</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >index</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf821_level0_row0" class="row_heading level0 row0" >your</th>
#       <td id="T_cf821_row0_col0" class="data row0 col0" >0.011359</td>
#       <td id="T_cf821_row0_col1" class="data row0 col1" >0.336283</td>
#       <td id="T_cf821_row0_col2" class="data row0 col2" >0.159292</td>
#       <td id="T_cf821_row0_col3" class="data row0 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row1" class="row_heading level0 row1" >what</th>
#       <td id="T_cf821_row1_col0" class="data row1 col0" >0.005715</td>
#       <td id="T_cf821_row1_col1" class="data row1 col1" >0.327434</td>
#       <td id="T_cf821_row1_col2" class="data row1 col2" >0.150442</td>
#       <td id="T_cf821_row1_col3" class="data row1 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row2" class="row_heading level0 row2" >but</th>
#       <td id="T_cf821_row2_col0" class="data row2 col0" >0.005105</td>
#       <td id="T_cf821_row2_col1" class="data row2 col1" >0.327434</td>
#       <td id="T_cf821_row2_col2" class="data row2 col2" >0.150442</td>
#       <td id="T_cf821_row2_col3" class="data row2 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row3" class="row_heading level0 row3" >How</th>
#       <td id="T_cf821_row3_col0" class="data row3 col0" >0.009608</td>
#       <td id="T_cf821_row3_col1" class="data row3 col1" >0.318584</td>
#       <td id="T_cf821_row3_col2" class="data row3 col2" >0.141593</td>
#       <td id="T_cf821_row3_col3" class="data row3 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row4" class="row_heading level0 row4" >my</th>
#       <td id="T_cf821_row4_col0" class="data row4 col0" >0.005732</td>
#       <td id="T_cf821_row4_col1" class="data row4 col1" >0.318584</td>
#       <td id="T_cf821_row4_col2" class="data row4 col2" >0.141593</td>
#       <td id="T_cf821_row4_col3" class="data row4 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row5" class="row_heading level0 row5" >we</th>
#       <td id="T_cf821_row5_col0" class="data row5 col0" >0.009383</td>
#       <td id="T_cf821_row5_col1" class="data row5 col1" >0.300885</td>
#       <td id="T_cf821_row5_col2" class="data row5 col2" >0.123894</td>
#       <td id="T_cf821_row5_col3" class="data row5 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row6" class="row_heading level0 row6" >are</th>
#       <td id="T_cf821_row6_col0" class="data row6 col0" >0.008059</td>
#       <td id="T_cf821_row6_col1" class="data row6 col1" >0.292035</td>
#       <td id="T_cf821_row6_col2" class="data row6 col2" >0.115044</td>
#       <td id="T_cf821_row6_col3" class="data row6 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row7" class="row_heading level0 row7" >can</th>
#       <td id="T_cf821_row7_col0" class="data row7 col0" >0.003486</td>
#       <td id="T_cf821_row7_col1" class="data row7 col1" >0.292035</td>
#       <td id="T_cf821_row7_col2" class="data row7 col2" >0.115044</td>
#       <td id="T_cf821_row7_col3" class="data row7 col3" >0.176991</td>
#     </tr>
#     <tr>
#       <th id="T_cf821_level0_row8" class="row_heading level0 row8" >not</th>
#       <td id="T_cf821_row8_col0" class="data row8 col0" >0.002427</td>
#       <td id="T_cf821_row8_col1" class="data row8 col1" >0.292035</td>
#       <td id="T_cf821_row8_col2" class="data row8 col2" >0.115044</td>
#       <td id="T_cf821_row8_col3" class="data row8 col3" >0.176991</td>

# %%
a = "Asle spiste med Putin".split()
b = "Quisling besøkte Hitler".split()
c = "En badedrakt kommer godt med i krig".split()

# %%
import numpy as np

# %%
avec = np.add.reduce([m[x] for x in a])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 avec = np.add.reduce([m[x] for x in a])
#
# Cell In[69], line 1, in <listcomp>(.0)
# ----> 1 avec = np.add.reduce([m[x] for x in a])
#
# NameError: name 'm' is not defined

# %%
bvec = np.add.reduce([m[x] for x in b])

# %%
cvec = np.add.reduce([m[x] for x in c])

# %%
from scipy.spatial.distance import cosine

# %%
cosine(bvec, cvec)
# Out:
# 0.8091326355934143

# %%
cosine(avec, bvec)
# Out:
# 0.3421650528907776

# %%
cosine(avec, cvec)
# Out:
# 0.5819809138774872

# %%
d['konge']
# Out:
# array([-0.09927908,  0.27863783,  0.08207181,  0.05657858, -0.13962978,
#        -0.1424493 ,  0.06331921,  0.30286202, -0.17559525, -0.08047769,
#         0.00869436, -0.27819964, -0.08409055, -0.01263583,  0.05935835,
#        -0.01269752,  0.20533673, -0.2027495 ,  0.00431319, -0.34668076,
#         0.10838543,  0.09876537,  0.17007446, -0.03127407,  0.01388995,
#         0.07690159, -0.07100473,  0.00100106, -0.16169405,  0.14132574,
#         0.29360393, -0.0108307 ,  0.15504372, -0.28619918, -0.02386783,
#         0.12967385,  0.07731283, -0.26178336, -0.11414833, -0.24678314,
#        -0.0167435 , -0.07253201, -0.14655782, -0.02129233,  0.10917688,
#         0.02041457, -0.04210058,  0.08376808,  0.00634978,  0.20020379,
#         0.04681044, -0.14323482, -0.09280784, -0.08289227, -0.17467651,
#         0.01492229,  0.08727186, -0.0657694 , -0.25182226, -0.07195269,
#         0.07373559,  0.08266725,  0.24257687, -0.03088325, -0.3018921 ,
#         0.19917484,  0.14292385,  0.22228958, -0.28303838,  0.07063959,
#        -0.0395919 ,  0.115677  ,  0.20653951,  0.03729171,  0.17956567,
#         0.15176585,  0.06507705,  0.12886849, -0.27880245,  0.09300892,
#        -0.08889981, -0.16530864,  0.01303826,  0.09167599, -0.05794204,
#        -0.01862866,  0.1255025 ,  0.15065685,  0.15294006, -0.0810457 ,
#         0.2944389 ,  0.12447131,  0.07661162, -0.02808404,  0.21770038,
#         0.0751093 ,  0.18963648, -0.13655452,  0.07733949,  0.14228521],
#       dtype=float32)

# %%
m['dronning']
# Out:
# array([-2.0357296 , -1.4922447 ,  1.9984303 ,  2.509681  ,  0.4678565 ,
#        -0.5607563 , -0.68748707, -1.6449172 , -2.849245  , -2.738875  ,
#        -0.6869653 , -1.3970499 , -3.6125734 ,  1.221389  , -1.6714805 ,
#        -2.4626887 ,  0.9088261 , -0.7730676 , -1.672319  , -0.1978911 ,
#        -2.8794448 ,  1.3136307 ,  3.7261515 ,  2.392581  ,  0.85708606,
#         0.96473825,  1.7944518 , -1.3518511 , -4.087831  , -2.3581512 ,
#        -1.5161412 , -0.9028114 , -2.1542652 ,  1.4666175 , -0.06540404,
#         2.6612759 , -0.2565892 , -3.331793  , -0.28736132,  2.047924  ,
#        -0.03520462,  0.6989206 , -0.40027627,  3.4016159 ,  0.3811961 ,
#        -3.9728603 ,  1.3520294 ,  2.1297576 , -1.1687332 ,  1.4254082 ],
#       dtype=float32)

# %%
kombo = (m['konge'] - m['mann']) + m['kvinne']

# %%
cosine(m['konge'], m['dronning'])
# Out:
# 0.22376716136932373

# %%
cosine(kombo, m['dronning'])
# Out:
# 0.23343390226364136
